# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
credit_card_data=pd.read_csv('/content/creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [5 rows x 31 columns]

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
#checking missing values
null_counts = credit_card_data.isnull().sum()
print(null_counts)
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
#sepereating
legit=credit_card_data[credit_card_data.Class==0]
fraud=credit_card_data[credit_card_data.Class==1]
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
#Statistics measure
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
plt.pie(credit_card_data['Class'].value_counts(),
        labels=['Legitimate', 'Fraudulent'], autopct='%1.1f%%', startangle=90)
plt.title('Class Distribution')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
legit_sample=legit.sample(n=492)

# %%
new_dataset=pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 19747    30523.0 -1.967483  1.005698  1.305223 -0.186093  0.654002 -0.614869
# 266659  162434.0 -1.008092  0.557652 -0.935958 -1.174631  1.744243 -1.043317
# 144057   85834.0 -1.644107 -1.862993  2.112118  0.920248  1.767172 -1.752790
# 110279   71754.0 -0.830161  1.555023  0.587943  1.438153  0.123901 -0.183473
# 88231    62049.0  0.593654 -1.355584  0.788457  0.507191 -1.489473 -0.264604
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 19747   0.625269 -0.115086 -0.158827  ...  0.062881  0.084909 -0.575108
# 266659  1.776194 -0.697085 -0.257326  ...  0.178217  1.136294  0.147359
# 144057 -1.235905  0.143495  1.027198  ...  0.242523  0.382100  0.483363
# 110279  0.807810  0.322853 -1.689419  ...  0.101086  0.107815 -0.198147
# 88231  -0.209167 -0.044421  1.126159  ... -0.036888 -0.558898 -0.204680
#
#              V24       V25       V26       V27       V28  Amount  Class
# 19747  -0.008164  0.648143 -0.455585 -0.530423  0.274865   16.20      0
# 266659  0.777277 -0.273099 -0.012427 -0.162271  0.033027   28.00      0
# 144057  0.340072 -1.049769 -0.780174  0.044901  0.072637    0.01      0
# 110279 -0.050782  0.527465 -0.073534 -0.046827  0.037933   84.24      0
# 88231   0.496318  0.028177  0.907086 -0.092370  0.070711  328.40      0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
#              V24       V25       V26       V27       V28  Amount  Class
# 279863 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00      1
# 280143 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76      1
# 280149  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89      1
# 281144 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00      1
# 281674 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53      1
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      93799.638636  0.057630  0.022462  0.024328  0.015909  0.017443
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.053102  0.059161  0.042017  0.061301  ... -0.000736 -0.006277
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.034502 -0.002986 -0.002099  0.015396 -0.008690 -0.027050 -0.019579
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       79.314432
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
plt.pie(new_dataset['Class'].value_counts(), labels=['Fraudulent','Legitimate' ],
        autopct='%1.1f%%', startangle=90)
plt.title('Class Distribution')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X = new_dataset[['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28','Amount']]
Y = new_dataset['Class']
correlation_matrix = X.corr().values if hasattr(X, 'corr') else np.corrcoef(X.T)
labels = X.columns if hasattr(X, 'columns') else [f"F{i}" for i in range(X.shape[1])]

plt.figure(figsize=(12, 10))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()

# Add annotations
for i in range(len(correlation_matrix)):
    for j in range(len(correlation_matrix)):
        plt.text(j, i, f"{correlation_matrix[i, j]:.2f}",
                 ha='center', va='center', color='black', fontsize=6)

plt.xticks(ticks=np.arange(len(labels)), labels=labels, rotation=90, fontsize=6)
plt.yticks(ticks=np.arange(len(labels)), labels=labels, fontsize=6)
plt.title('Feature-Feature Correlation Heatmap')
plt.tight_layout()
plt.show()

# %%
X = X.drop(columns = ["V3", "V11", "V12", "V5", "V17", "V18"])

# %%
print(X)
# Out:
#             Time        V1        V2        V4        V6        V7        V8  \
# 19747    30523.0 -1.967483  1.005698 -0.186093 -0.614869  0.625269 -0.115086
# 266659  162434.0 -1.008092  0.557652 -1.174631 -1.043317  1.776194 -0.697085
# 144057   85834.0 -1.644107 -1.862993  0.920248 -1.752790 -1.235905  0.143495
# 110279   71754.0 -0.830161  1.555023  1.438153 -0.183473  0.807810  0.322853
# 88231    62049.0  0.593654 -1.355584  0.507191 -0.264604 -0.209167 -0.044421
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653  1.749293 -2.010494 -0.882850  0.697211
# 280143  169347.0  1.378559  1.289381  1.411850 -1.326536 -1.413170  0.248525
# 280149  169351.0 -0.676143  1.126366  0.468308 -0.003346 -2.234739  1.210158
# 281144  169966.0 -3.113832  0.585864  1.817092 -2.943548 -2.208002  1.058733
# 281674  170348.0  1.991976  0.158476  0.408670 -0.096695  0.223050 -0.068384
#
#               V9       V10       V13  ...       V20       V21       V22  \
# 19747  -0.158827  0.380035 -1.259623  ... -0.376176  0.062881  0.084909
# 266659 -0.257326  0.361326  0.126282  ... -0.383454  0.178217  1.136294
# 144057  1.027198 -0.225629 -0.808942  ...  0.359420  0.242523  0.382100
# 110279 -1.689419 -0.690153  0.905496  ...  0.332033  0.101086  0.107815
# 88231   1.126159 -0.609087  0.306589  ...  0.591406 -0.036888 -0.558898
# ...          ...       ...       ...  ...       ...       ...       ...
# 279863 -2.064945 -5.587794 -1.235123  ...  1.252967  0.778584 -0.319189
# 280143 -1.127396 -3.232153 -0.792532  ...  0.226138  0.370612  0.028234
# 280149 -0.652250 -3.463891 -0.418950  ...  0.247968  0.751826  0.834108
# 281144 -1.632333 -5.245984 -1.127455  ...  0.306271  0.583276 -0.269209
# 281674  0.577829 -0.888722  0.380428  ... -0.017652 -0.164350 -0.295135
#
#              V23       V24       V25       V26       V27       V28  Amount
# 19747  -0.575108 -0.008164  0.648143 -0.455585 -0.530423  0.274865   16.20
# 266659  0.147359  0.777277 -0.273099 -0.012427 -0.162271  0.033027   28.00
# 144057  0.483363  0.340072 -1.049769 -0.780174  0.044901  0.072637    0.01
# 110279 -0.198147 -0.050782  0.527465 -0.073534 -0.046827  0.037933   84.24
# 88231  -0.204680  0.496318  0.028177  0.907086 -0.092370  0.070711  328.40
# ...          ...       ...       ...       ...       ...       ...     ...
# 279863  0.639419 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00
# 280143 -0.145640 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76
# 280149  0.190944  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89
# 281144 -0.456108 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00
# 281674 -0.072173 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53
#
# [984 rows x 24 columns]

# %%
print(Y)
# Out:
# 19747     0
# 266659    0
# 144057    0
# 110279    0
# 88231     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
def train_test_split(X, y, test_size=0.2, shuffle=True):
    assert len(X) == len(y)
    indices = np.arange(len(X))
    if shuffle:
        np.random.shuffle(indices)
    split_idx = int(len(X) * (1 - test_size))
    train_idx, test_idx = indices[:split_idx], indices[split_idx:]
    # Use iloc to index by row numbers
    return X.iloc[train_idx], X.iloc[test_idx], y.iloc[train_idx], y.iloc[test_idx]

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (984, 24) (787, 24) (197, 24)

# %%
def min_max_scale_fit(X):
    """Fit function: calculate min and max for each column"""
    min_vals = np.min(X, axis=0)
    max_vals = np.max(X, axis=0)
    return min_vals, max_vals

def min_max_scale_transform(X, min_vals, max_vals):
    """Transform function: scale using the previously calculated min and max"""
    denom = max_vals - min_vals
    denom[denom == 0] = 1  # Prevent division by zero
    return (X - min_vals) / denom

# Convert to NumPy arrays
X_train_np = X_train.to_numpy()
X_test_np = X_test.to_numpy()

# Fit on training data
min_vals, max_vals = min_max_scale_fit(X_train_np)

# Transform training and testing data using same scaling
X_train_scaled = min_max_scale_transform(X_train_np, min_vals, max_vals)
X_test_scaled = min_max_scale_transform(X_test_np, min_vals, max_vals)

# %%
import numpy as np

def pca(X, n_components=2, fit=True):
    """
    Performs Principal Component Analysis (PCA) on the data.

    Args:
        X (numpy.ndarray): The input data.
        n_components (int, optional): Number of principal components to keep. Defaults to 2.
        fit (bool, optional): Whether to fit the PCA model. Defaults to True.

    Returns:
        numpy.ndarray: The transformed data.
        numpy.ndarray: The principal components (eigenvectors).
    """

    X_meaned = X - np.mean(X, axis=0)
    cov_mat = np.cov(X_meaned, rowvar=False)
    eig_vals, eig_vecs = np.linalg.eigh(cov_mat)
    sorted_indices = np.argsort(eig_vals)[::-1]
    principal_components = eig_vecs[:, sorted_indices]
    principal_components = principal_components[:, :n_components]

    #Removed self here as it was not needed since the function is not a method within a class
    #if fit:  # Fit the model by storing principal components
    #    self.principal_components = principal_components

    transformed_data = np.dot(X_meaned, principal_components)  # Transform the data

    if fit:
        return transformed_data, principal_components
    else:
        return transformed_data


# Usage:
# Fit and transform the training data
X_train_pca, principal_components = pca(X_train_scaled, n_components=2, fit=True)

# Transform the test data using the fitted principal components
X_test_pca = pca(X_test_scaled, n_components=2, fit=False)

# %%
class GaussianNaiveBayes:
    def __init__(self):
        self.classes = None
        self.mean = None
        self.variance = None
        self.prior = None

    def fit(self, X, y):
        self.classes = np.unique(y)
        self.mean = np.zeros((len(self.classes), X.shape[1]))
        self.variance = np.zeros((len(self.classes), X.shape[1]))
        self.prior = np.zeros(len(self.classes))

        for i, c in enumerate(self.classes):
            X_c = X[y == c]
            self.mean[i, :] = X_c.mean(axis=0)
            self.variance[i, :] = X_c.var(axis=0) + 1e-6
            self.prior[i] = X_c.shape[0] / X.shape[0]

    def predict(self, X):
        return np.array([self._predict_single(x) for x in X])

    def _predict_single(self, x):
        posteriors = []
        for i, c in enumerate(self.classes):
            prior = np.log(self.prior[i])
            likelihood = np.sum(np.log(self._gaussian_pdf(x, self.mean[i], self.variance[i])))
            posteriors.append(prior + likelihood)
        return self.classes[np.argmax(posteriors)]

    def _gaussian_pdf(self, x, mean, var):
     eps = 1e-9  # Avoid division by 0 and log(0)
     coef = 1.0 / np.sqrt(2.0 * np.pi * var)
     exponent = np.exp(-((x - mean) ** 2) / (2 * var))
     return np.clip(coef * exponent, eps, None)

# %%
naive_bayes_model = GaussianNaiveBayes()
#decision_tree_model = DecisionTree(random_state=2)

# Fit the models to the training data
naive_bayes_model.fit(X_train_scaled, Y_train)
#decision_tree_model.fit(X_train_scaled, Y_train)

# Make predictions
y_pred_nb_test = naive_bayes_model.predict(X_test_scaled)
#y_pred_dt_test = decision_tree_model.predict(X_test_scaled)

# %%
# Node class for the Decision Tree
class Node:
    def __init__(self, feature=None, threshold=None, left=None, right=None, value=None):
        self.feature = feature
        self.threshold = threshold
        self.left = left
        self.right = right
        self.value = value

# Decision Tree Class (Custom C4.5 style, use gini impurity of cart style)
class DecisionTree:
    def __init__(self, max_depth=None, min_samples_split=2, **kwargs):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.root = None

    def _gini_impurity(self, y):
        unique_classes, counts = np.unique(y, return_counts=True)
        impurity = 1 - np.sum((counts / len(y)) ** 2)
        return impurity

    def _best_split(self, X, y):
        best_feature, best_threshold = None, None
        best_gini = float('inf')

        # Get the number of features (columns) in X
        num_features = X.shape[1]

        for feature in range(num_features):
            # Get unique values for the current feature
            # Use X[:, feature] to access the feature column for NumPy arrays
            thresholds = np.unique(X[:, feature])

            for threshold in thresholds:
                # Use boolean indexing for NumPy arrays
                left_idx = X[:, feature] <= threshold
                right_idx = X[:, feature] > threshold

                if len(y[left_idx]) >= self.min_samples_split and len(y[right_idx]) >= self.min_samples_split:
                    gini_left = self._gini_impurity(y[left_idx])
                    gini_right = self._gini_impurity(y[right_idx])
                    gini_split = (len(y[left_idx]) / len(y)) * gini_left + (len(y[right_idx]) / len(y)) * gini_right
                    if gini_split < best_gini:
                        best_gini = gini_split
                        best_feature = feature
                        best_threshold = threshold
        return best_feature, best_threshold

    def _build_tree(self, X, y, depth=0):
        if depth == self.max_depth or len(np.unique(y)) == 1 or len(y) < self.min_samples_split:
            most_common = np.bincount(y).argmax()
            return Node(value=most_common)

        best_feature, best_threshold = self._best_split(X, y)
        if best_feature is None:
            most_common = np.bincount(y).argmax()
            return Node(value=most_common)

        # Use boolean indexing for NumPy arrays
        left_idx = X[:, best_feature] <= best_threshold
        right_idx = X[:, best_feature] > best_threshold

        left_subtree = self._build_tree(X[left_idx], y[left_idx], depth + 1)
        right_subtree = self._build_tree(X[right_idx], y[right_idx], depth + 1)

        return Node(feature=best_feature, threshold=best_threshold, left=left_subtree, right=right_subtree)

    def fit(self, X, y):
        self.root = self._build_tree(X, y)

    def _predict_single(self, x, node):
        if node.value is not None:
            return node.value
        # Access feature using NumPy array indexing
        if x[node.feature] <= node.threshold:
            return self._predict_single(x, node.left)
        else:
            return self._predict_single(x, node.right)
    def predict(self, X):
        return np.array([self._predict_single(x, self.root) for x in X]) # Changed to iterate over rows of X

# %%
#naive_bayes_model = GaussianNaiveBayes()
decision_tree_model = DecisionTree(random_state=2)

# Fit the models to the training data
#naive_bayes_model.fit(X_train_scaled, Y_train)
decision_tree_model.fit(X_train_scaled, Y_train)

# Make predictions
#y_pred_nb_test = naive_bayes_model.predict(X_test_scaled)
y_pred_dt_test = decision_tree_model.predict(X_test_scaled)

# %%
def accuracy_score(y_true, y_pred):
    return (y_true == y_pred).sum() / len(y_true)

def precision_score(y_true, y_pred):
    TP = ((y_true == 1) & (y_pred == 1)).sum()
    FP = ((y_true == 0) & (y_pred == 1)).sum()
    # Return 1 if denominator is 0 to avoid division by zero error
    return TP / (TP + FP) if (TP + FP) != 0 else 1

def recall_score(y_true, y_pred):
    TP = ((y_true == 1) & (y_pred == 1)).sum()
    FN = ((y_true == 1) & (y_pred == 0)).sum()
    # Return 1 if denominator is 0 to avoid division by zero error
    return TP / (TP + FN) if (TP + FN) != 0 else 1

def f1_score(y_true, y_pred):
    prec = precision_score(y_true, y_pred)
    rec = recall_score(y_true, y_pred)
    # Return 1 if denominator is 0 to avoid division by zero error
    return 2 * prec * rec / (prec + rec) if (prec + rec) != 0 else 1

# %%
def plot_confusion_matrix(y_true, y_pred, labels):
    import numpy as np
    import matplotlib.pyplot as plt

    matrix = np.zeros((2, 2), dtype=int)
    for t, p in zip(y_true, y_pred):
        matrix[int(t)][int(p)] += 1

    fig, ax = plt.subplots()
    cax = ax.matshow(matrix, cmap='Blues')
    plt.colorbar(cax)
    for (i, j), val in np.ndenumerate(matrix):
        ax.text(j, i, f'{val}', ha='center', va='center')

    ax.set_xticklabels([''] + labels)
    ax.set_yticklabels([''] + labels)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

    # Return the confusion matrix
    return matrix

# %%
# Assuming 'plot_confusion_matrix' is your custom function
conf_matrix_nb = plot_confusion_matrix(Y_test, y_pred_nb_test, labels=['0', '1'])
print("Confusion Matrix (Gaussian Naive Bayes):\n", conf_matrix_nb)

conf_matrix_dt = plot_confusion_matrix(Y_test, y_pred_dt_test, labels=['0', '1'])
print("Confusion Matrix (Decision Tree):\n", conf_matrix_dt)
# Out:
# <ipython-input-207-b9154ab3faac>:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([''] + labels)
# <ipython-input-207-b9154ab3faac>:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([''] + labels)
# <ipython-input-207-b9154ab3faac>:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([''] + labels)
# <ipython-input-207-b9154ab3faac>:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([''] + labels)
# Confusion Matrix (Gaussian Naive Bayes):
#  [[87  6]
#  [21 83]]
# Confusion Matrix (Decision Tree):
#  [[86  7]
#  [11 93]]

# %%
# Calculate and print the F1 scores
f1_nb = f1_score(Y_test, y_pred_nb_test)
print("F1 Score (Gaussian Naive Bayes):", f1_nb)

f1_dt = f1_score(Y_test, y_pred_dt_test)
print("F1 Score (Decision Tree):", f1_dt)
# Out:
# F1 Score (Gaussian Naive Bayes): 0.8601036269430051
# F1 Score (Decision Tree): 0.911764705882353

# %%
# Calculate and print the precision scores
precision_nb = precision_score(Y_test, y_pred_nb_test)
print("Precision Score (Gaussian Naive Bayes):", precision_nb)

precision_dt = precision_score(Y_test, y_pred_dt_test)
print("Precision Score (Decision Tree):", precision_dt)
# Out:
# Precision Score (Gaussian Naive Bayes): 0.9325842696629213
# Precision Score (Decision Tree): 0.93

# %%
# Calculate and print the recall scores
recall_nb = recall_score(Y_test, y_pred_nb_test)
print("Recall Score (Gaussian Naive Bayes):", recall_nb)

recall_dt = recall_score(Y_test, y_pred_dt_test)
print("Recall Score (Decision Tree):", recall_dt)
# Out:
# Recall Score (Gaussian Naive Bayes): 0.7980769230769231
# Recall Score (Decision Tree): 0.8942307692307693

# %%
# Naive Bayes accuracy on training data:
x_train_predict_nb = naive_bayes_model.predict(X_train_scaled)
training_data_accuracy_nb = accuracy_score(x_train_predict_nb, Y_train)
print("Training Accuracy with Gaussian Naive Bayes: {:.10f}".format(training_data_accuracy_nb))

# Decision Tree accuracy on training data:
decision_tree_model = DecisionTree(random_state=2, max_depth=5, min_samples_split=20)
decision_tree_model.fit(X_train_scaled, Y_train)
x_train_predict_dt = decision_tree_model.predict(X_train_scaled)
training_data_accuracy_dt = accuracy_score(x_train_predict_dt, Y_train)
print("Training Accuracy with Decision Tree (C4.5): {:.10f}".format(training_data_accuracy_dt))
# Out:
# Training Accuracy with Gaussian Naive Bayes: 0.9059720457
# Training Accuracy with Decision Tree (C4.5): 0.9402795426

# %%
# Make predictions and evaluate for naive bayes
y_pred_nb = naive_bayes_model.predict(X_test_scaled)
accuracy_nb = accuracy_score(y_pred_nb, Y_test)
print("Test Accuracy with Gaussian Naive Bayes:", accuracy_nb)

# Make predictions and evaluate for custom c4.5
y_pred_dt = decision_tree_model.predict(X_test_scaled)
accuracy_dt = accuracy_score(y_pred_dt, Y_test)
print("Test Accuracy with Decision Tree (C4.5):", accuracy_dt)
# Out:
# Test Accuracy with Gaussian Naive Bayes: 0.8629441624365483
# Test Accuracy with Decision Tree (C4.5): 0.9289340101522843
